# %% [markdown]
# # Basics

# %% [markdown]
# 1. What is a neuron?
#    * A thing that holds a number basically.
# 2. What does a weight represent?
#    *
# 4. What does an activation function do?
#    * triggers another neuron in another layer
# 6. Why do we need multiple layers?
#    * coz one neuron has one property for example a part of component of the image, and thenm the next layer's neuron is a component which points to smt in output. basically to build up that picture or the output.

# %% [markdown]
# # Gradient Descent, how nets learn?

# %% [markdown]
# 1. What is the loss function measuring?
#     * it is a difference of squares of the output gotten from the net, and the output you want. the higer the number the more trash the value is, and in order to reduce the cost, you need to find the critical point (min) of the cost function using slope of tan. but this is for 1 input, for 2 inputs gradient descent comes into play.
#     * ![image.png](attachment:8057d191-2b52-4d40-83dd-fdbb78fb8473.png) similar to this
# 2. What does gradient descent do step by step?
#     * it basically gives you the direction to step that decreases the function most quickly. This requires mutivariavle calculus which i didn't study yet. overall, its like finding local minimum.
# 3. What does backprop calculate?
#     * its an idea of back tracking while traing the data. coz you want a desired output and the net throws smt diff. so you go back and look into the neuron and their weights and activation and stuff, and you determine how much it needs to be adjusted, little, much or wtv.  you sum for all of them and you get an avg for that. so basically backprop is like a list of nudges that you want to happen to the second to last layer. And then you can repeat the same process to move backwards in this net.
# 4. What happens if learning rate is too high?
#     * idk
